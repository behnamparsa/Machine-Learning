# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %%
# Reading a CSV
df = pd.read_csv('possum.csv')
df
# Out:
#      case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0       1     1    Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1       2     1    Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2       3     1    Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3       4     1    Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4       5     1    Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
# ..    ...   ...    ...  ..  ...      ...     ...       ...    ...       ...
# 99    100     7  other   m  1.0     89.5    56.0      81.5   36.5      66.0
# 100   101     7  other   m  1.0     88.6    54.7      82.5   39.0      64.4
# 101   102     7  other   f  6.0     92.4    55.0      89.0   38.0      63.5
# 102   103     7  other   m  4.0     91.5    55.2      82.5   36.5      62.9
# 103   104     7  other   f  3.0     93.6    59.9      89.0   40.0      67.6
#
#      earconch   eye  chest  belly
# ...

# %%
df.loc[[2,1],:]
# Out:
#    case  site  Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 2     3     1  Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 1     2     1  Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
#
#    earconch   eye  chest  belly
# 2      51.9  15.5   30.0   34.0
# 1      51.2  16.0   28.5   33.0

# %%
df.loc[[2,3], ['sex', 'age']]
# Out:
#   sex  age
# 2   f  6.0
# 3   f  6.0

# %% [markdown]
# The code sets the index of the DataFrame to the 'age' column and then returns all rows with an index label of 2, along with all of the columns for those rows.
#
# This line of code would select all rows in the DataFrame where the value in the 'age' column is 2, and return all columns for those rows.

# %%
df.set_index('age').loc[2,:]
# Out:
#      case  site    Pop sex  hdlngth  skullw  totlngth  taill  footlgth  \
# age
# 2.0     5     1    Vic   f     91.5    56.3      85.5   36.0      71.0
# 2.0     7     1    Vic   m     95.3    58.2      89.5   36.0      71.5
# 2.0    18     1    Vic   m     93.5    55.7      90.0   36.0      73.7
# 2.0    24     1    Vic   m     94.4    54.9      84.0   34.0      75.0
# 2.0    27     1    Vic   f     90.5    54.5      85.0   35.0      70.3
# 2.0    30     1    Vic   f     92.1    54.4      84.0   33.5      70.6
# 2.0    34     2    Vic   m     90.6    55.7      85.5   36.5      73.1
# 2.0    37     2    Vic   f     89.3    54.8      82.5   35.0      71.2
# 2.0    43     2    Vic   f     90.0    55.5      81.0   32.0      72.0
# 2.0    47     3  other   m     90.1    54.8      89.0   37.5      66.0
# 2.0    55     4  other   m    103.1    63.2      92.5   38.0      72.5
# 2.0    59     4  other   m    102.5    62.8      96.0   40.0      73.2
# ...

# %% [markdown]
# The `iloc` attribute is used to access rows and columns in a Pandas DataFrame by integer index. It is similar to the `loc` attribute, but `iloc` only uses integer-based indexing, whereas `loc` can use either integer-based or label-based indexing.

# %%
df.set_index('age').iloc[2,:]
# Out:
# case           3
# site           1
# Pop          Vic
# sex            f
# hdlngth     94.0
# skullw      60.0
# totlngth    95.5
# taill       39.0
# footlgth    75.4
# earconch    51.9
# eye         15.5
# chest       30.0
# belly       34.0
# Name: 6.0, dtype: object

# %%
df.set_index('age')
# Out:
#      case  site    Pop sex  hdlngth  skullw  totlngth  taill  footlgth  \
# age
# 8.0     1     1    Vic   m     94.1    60.4      89.0   36.0      74.5
# 6.0     2     1    Vic   f     92.5    57.6      91.5   36.5      72.5
# 6.0     3     1    Vic   f     94.0    60.0      95.5   39.0      75.4
# 6.0     4     1    Vic   f     93.2    57.1      92.0   38.0      76.1
# 2.0     5     1    Vic   f     91.5    56.3      85.5   36.0      71.0
# ..    ...   ...    ...  ..      ...     ...       ...    ...       ...
# 1.0   100     7  other   m     89.5    56.0      81.5   36.5      66.0
# 1.0   101     7  other   m     88.6    54.7      82.5   39.0      64.4
# 6.0   102     7  other   f     92.4    55.0      89.0   38.0      63.5
# 4.0   103     7  other   m     91.5    55.2      82.5   36.5      62.9
# 3.0   104     7  other   f     93.6    59.9      89.0   40.0      67.6
#
#      earconch   eye  chest  belly
# age
# 8.0      54.5  15.2   28.0   36.0
# ...

# %%
df = df.sort_values('age', ascending=False)
df
# Out:
#      case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 10     11     1    Vic   f  9.0     93.3    57.2      89.5   39.0      77.2
# 8       9     1    Vic   f  9.0     93.4    56.3      91.5   37.0      72.4
# 0       1     1    Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 93     94     7  other   m  7.0     91.8    57.6      84.0   35.5      64.2
# 69     70     5  other   f  7.0     91.9    56.4      87.0   38.0      65.4
# ..    ...   ...    ...  ..  ...      ...     ...       ...    ...       ...
# 99    100     7  other   m  1.0     89.5    56.0      81.5   36.5      66.0
# 100   101     7  other   m  1.0     88.6    54.7      82.5   39.0      64.4
# 16     17     1    Vic   f  1.0     94.7    67.7      89.5   36.5      73.2
# 43     44     2    Vic   m  NaN     85.1    51.5      76.0   35.5      70.3
# 45     46     2    Vic   m  NaN     91.4    54.4      84.0   35.0      72.8
#
#      earconch   eye  chest  belly
# ...

# %%
df.loc[:,'age'].mean()
# Out:
# 3.8333333333333335

# %%
df['age'] < df['age'].mean()
# Out:
# 10     False
# 8      False
# 0      False
# 93     False
# 69     False
#        ...
# 99      True
# 100     True
# 16      True
# 43     False
# 45     False
# Name: age, Length: 104, dtype: bool

# %%
df.loc[df['age'] < df['age'].mean(),:]
# Out:
#      case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 65     66     5  other   f  3.0     90.4    55.8      86.0   36.5      63.2
# 96     97     7  other   m  3.0     91.0    53.1      86.0   38.0      63.8
# 98     99     7  other   f  3.0     93.3    56.2      86.5   38.5      64.8
# 80     81     6  other   m  3.0     90.6    56.0      85.5   38.0      65.6
# 82     83     6  other   f  3.0     90.0    53.8      81.5   36.0      62.0
# 83     84     6  other   m  3.0     88.4    54.6      80.5   36.0      62.6
# 63     64     5  other   f  3.0     96.9    56.5      89.5   38.5      63.0
# 85     86     6  other   f  3.0     88.2    53.2      86.5   38.5      60.3
# 89     90     7  other   m  3.0     92.6    54.6      85.0   38.5      69.8
# 90     91     7  other   m  3.0     97.8    59.6      89.0   38.0      65.5
# 92     93     7  other   m  3.0     89.2    54.0      82.0   38.0      63.8
# ...

# %%
df.shape
# Out:
# (104, 14)

# %%
df.columns
# Out:
# Index(['case', 'site', 'Pop', 'sex', 'age', 'hdlngth', 'skullw', 'totlngth',
#        'taill', 'footlgth', 'earconch', 'eye', 'chest', 'belly'],
#       dtype='object')

# %%
df['whatever'] = df['taill'] / df['totlngth']

# %%
df
# Out:
#      case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0       1     1    Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1       2     1    Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2       3     1    Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3       4     1    Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4       5     1    Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
# ..    ...   ...    ...  ..  ...      ...     ...       ...    ...       ...
# 99    100     7  other   m  1.0     89.5    56.0      81.5   36.5      66.0
# 100   101     7  other   m  1.0     88.6    54.7      82.5   39.0      64.4
# 101   102     7  other   f  6.0     92.4    55.0      89.0   38.0      63.5
# 102   103     7  other   m  4.0     91.5    55.2      82.5   36.5      62.9
# 103   104     7  other   f  3.0     93.6    59.9      89.0   40.0      67.6
#
#      earconch   eye  chest  belly
# ...

# %%
df['age'].to_numpy()
# Out:
# array([ 8.,  6.,  6.,  6.,  2.,  1.,  2.,  6.,  9.,  6.,  9.,  5.,  5.,
#         3.,  5.,  4.,  1.,  2.,  5.,  4.,  3.,  3.,  4.,  2.,  3.,  7.,
#         2.,  4.,  3.,  2.,  3.,  4.,  3.,  2.,  4.,  7.,  2.,  7.,  1.,
#         3.,  5.,  3.,  2., nan,  3., nan,  2.,  5.,  4.,  5.,  5.,  6.,
#         3.,  7.,  2.,  3.,  4.,  3.,  2.,  2.,  7.,  3.,  6.,  3.,  5.,
#         3.,  4.,  5.,  5.,  7.,  6.,  1.,  1.,  4.,  6.,  5.,  6.,  1.,
#         1.,  1.,  3.,  4.,  3.,  3.,  3.,  3.,  2.,  2.,  6.,  3.,  3.,
#         2.,  3.,  7.,  4.,  4.,  3.,  5.,  3.,  1.,  1.,  6.,  4.,  3.])

# %% [markdown]
# In Pandas, a `Series` is a one-dimensional labeled array capable of holding any data type. It is similar to a column in a spreadsheet. You can think of it as a dictionary with a key (the label) and a value (the data).
#
# A `DataFrame` is a 2-dimensional labeled data structure with columns of potentially different types. You can think of it like a spreadsheet or a SQL table, or a dictionary of Series objects. It is generally the most commonly used Pandas object.

# %%
pd.Series([2,32,2,1,3])
# Out:
# 0     2
# 1    32
# 2     2
# 3     1
# 4     3
# dtype: int64

# %%
pd.DataFrame([{'age':22},{'age':23},{'age':24}])
# Out:
#    age
# 0   22
# 1   23
# 2   24

# %% [markdown]
# The `groupby()` function is used to split the data into groups based on some criteria.

# %%
df.groupby('site')['age'].mean()
# Out:
# site
# 1    4.181818
# 2    3.545455
# 3    4.285714
# 4    3.285714
# 5    4.307692
# 6    3.307692
# 7    3.444444
# Name: age, dtype: float64

# %% [markdown]
# # Advanced Python

# %% [markdown]
# ### Always prefer numpy operations

# %%
import numpy as np
x = np.random.random(10)

# %%
# %%time
sum(x)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# np.float64(5.098528772627895)

# %%
# %%time
np.sum(x)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# np.float64(5.098528772627895)

# %% [markdown]
# ### Always prefer vector operations over loops

# %%
a = np.random.rand(1000, 1000)
b = np.random.rand(1000)

# %%
import numpy as np
import timeit
import time
# %%timeit
x = np.dot(a, b)
print(x)
# Out:
# UsageError: Line magic function `%%timeit` not found.

# %%
# %%timeit
x = np.zeros(1000)

for i in range(1000):
  for j in range(1000):
    x[i] += a[i, j] * b[j]
# Out:
# 544 ms ± 18.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%time
df.loc[:, 'age'] += 1
# Out:
# CPU times: total: 0 ns
# Wall time: 998 μs

# %%
# %%time
for index, row in df.iterrows():
  df.loc[index, 'age'] += 1
# Out:
# CPU times: total: 15.6 ms
# Wall time: 36.8 ms

# %% [markdown]
# ### Python class and inheritance

# %%
class Animal:
    def __init__(self, name, num_legs):
        self.name = name
        self.num_legs = num_legs
    
    def classify(self):
        if self.num_legs == 0:
            return "I am a snake!"
        elif self.num_legs == 4:
            return "I am a dog!"
        elif self.num_legs == 2:
            return "I am a human!"
        else:
            return "I am an unknown species!"

    def sound(self):
      pass

# %%
class Dog(Animal):
    def __init__(self, name, breed, fur_color):
        super().__init__(name, 4)
        self.breed = breed
        self.fur_color = fur_color

    def sound(self):
        print('Bark')

# %%
dog = Dog("Fido", "Labrador", "brown")

# %%
dog.classify()
# Out:
# 'I am a dog!'

# %%
dog.sound()
# Out:
# Bark
