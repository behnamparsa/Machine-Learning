# %%
# bring our packages

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load in data

df=pd.read_csv("C:\GitHub\Machine-Learning\data\HR_file.csv")

# %%
df.describe().T
# Out:
#                          count        mean        std    min     25%     50%  \
# satisfaction_level     14999.0    0.612834   0.248631   0.09    0.44    0.64
# last_evaluation        14999.0    0.716102   0.171169   0.36    0.56    0.72
# number_project         14999.0    3.803054   1.232592   2.00    3.00    4.00
# average_montly_hours   14999.0  201.050337  49.943099  96.00  156.00  200.00
# time_spend_company     14999.0    3.498233   1.460136   2.00    3.00    3.00
# Work_accident          14999.0    0.144610   0.351719   0.00    0.00    0.00
# left                   14999.0    0.238083   0.425924   0.00    0.00    0.00
# promotion_last_5years  14999.0    0.021268   0.144281   0.00    0.00    0.00
#
#                           75%    max
# satisfaction_level       0.82    1.0
# last_evaluation          0.87    1.0
# number_project           5.00    7.0
# average_montly_hours   245.00  310.0
# time_spend_company       4.00   10.0
# Work_accident            0.00    1.0
# ...

# %%
df2 = df[["time_spend_company","satisfaction_level","last_evaluation","average_montly_hours"]]

df2.corr()
# Out:
#                       time_spend_company  satisfaction_level  last_evaluation  \
# time_spend_company              1.000000           -0.100866         0.131591
# satisfaction_level             -0.100866            1.000000         0.105021
# last_evaluation                 0.131591            0.105021         1.000000
# average_montly_hours            0.127755           -0.020048         0.339742
#
#                       average_montly_hours
# time_spend_company                0.127755
# satisfaction_level               -0.020048
# last_evaluation                   0.339742
# average_montly_hours              1.000000

# %% [markdown]
# # Visual Analysis
# univariate, bivariate, multivariate analysis

# %%
# which department
df.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# Departments               object
# salary                    object
# dtype: object

# %%
plt.style.use('ggplot')
plt.figure(figsize=(8,5))
df.groupby('Departments')['left'].sum().plot(kind='barh')
# Out:
# <Axes: ylabel='Departments'>

# %%
plt.figure(figsize=(8,5))
plt.scatter(x=df['satisfaction_level'],y=df['last_evaluation'], c='blue',marker='*')
plt.title("Bivariate Analysis: Satisfaction Vs Evaluation");
plt.savefig("correlation.png")

# %%
plt.figure(figsize=(8,8))
sns.displot(df['satisfaction_level'])

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['Departments'],y = df['satisfaction_level']);

# %%
sns.heatmap(df2.corr(),annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(8,8))
sns.violinplot(x=df['salary'],y=df['satisfaction_level'])
# Out:
# <Axes: xlabel='salary', ylabel='satisfaction_level'>

# %%
sns.pairplot(df)
