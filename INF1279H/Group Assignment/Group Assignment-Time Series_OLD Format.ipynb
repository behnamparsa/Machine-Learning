# %% [markdown]
# Step 1: Upload the Data and perform the initial inspection
# - Target Value: 'TOT_PAID' and date column: 'ACC_MONTH'
# - Feature Columns: 'EST_COST', 'NBR_CASE' = 'NBR_KEY_CASE' + 'NBR_OTHER'
# due to the mathematical equation between case related fields only one of them along with the 'EST_COST' has the potential to be a valid regressor

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import grangercausalitytests
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from prophet import Prophet


# Load Dataset
data = pd.read_csv("C:/GitHub/Machine-Learning/data/Payment Data.csv")

# dataset preprocess
data['ACC_MONTH'] = pd.to_datetime(data['ACC_MONTH'])
df = data[['ACC_MONTH', 'TOT_PAID', 'EST_COST', 'NBR_CASE', 'NBR_KEY_CASE','NBR_OTHER']].dropna()
df = data.sort_values(by='ACC_MONTH')


# Plot the trend of TOT_PAID
plt.figure(figsize=(12, 6))
plt.plot(df['ACC_MONTH'], df['TOT_PAID'], marker='o', linestyle='-')
plt.title('Monthly Expenditures Trend Over Time (Monthly)',fontsize=24)
plt.xlabel('Month')
plt.ylabel('TOT_PAID')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Step 2: Correlation and Lag analysis, using statistical test: Garnger Casuality
#
# Calculating the correlation between the target value and potential regressors, running a lag correlation analysis and testing the best lag’s significance by Granger Casualty Test and finalizing the potential regressors and their lag in the model

# %%
2.1 #Correlation Analysis
import numpy as np
from scipy.stats import pearsonr


# Select numeric features for correlation
features = ['NBR_CASE', 'NBR_OTHER', 'NBR_KEY_CASE']
df_corr = df[features].dropna()

# Initialize empty DataFrames for correlations and p-values
corr_matrix = pd.DataFrame(index=features, columns=features, dtype=float)
pval_matrix = pd.DataFrame(index=features, columns=features, dtype=float)

# Compute Pearson correlation and p-values
for col1 in features:
    for col2 in features:
        corr, pval = pearsonr(df_corr[col1], df_corr[col2])
        corr_matrix.loc[col1, col2] = corr
        pval_matrix.loc[col1, col2] = pval

# Display the correlation matrix
print("\Pearson Correlation Coefficients:")
print(corr_matrix.round(3))

# Display the p-value matrix
print("\nP-values of Pearson Correlation Tests:")
print(pval_matrix.round(4))

# Optional: Plot correlation matrix
plt.figure(figsize=(5,5))
sns.heatmap(corr_matrix.astype(float), annot=True, fmt=".2f", cmap="coolwarm", square=True)
plt.title("Pearson Correlation: Coefficient",fontsize=10)
plt.tight_layout()
plt.show()

# Optional: Plot p-values
plt.figure(figsize=(5, 5))
sns.heatmap(pval_matrix.astype(float), annot=True, fmt=".4f", cmap="Reds", square=True)
plt.title("Pearson Correlation: P-Value",fontsize=10)
plt.tight_layout()
plt.show()


# output: As we expected: NBR_CASE has significant intercorrelation with NBR_KEY_CASE(0.6) and NBR_OTHER (0.92) (NBR_CASE = NBR_KEY_CASE + NBR_OTHER)
# we can skip this stage as it does not have much to add to this analysis
# Out:
# \Pearson Correlation Coefficients:
#               NBR_CASE  NBR_OTHER  NBR_KEY_CASE
# NBR_CASE         1.000      0.919         0.604
# NBR_OTHER        0.919      1.000         0.241
# NBR_KEY_CASE     0.604      0.241         1.000
#
# P-values of Pearson Correlation Tests:
#               NBR_CASE  NBR_OTHER  NBR_KEY_CASE
# NBR_CASE           0.0     0.0000        0.0000
# NBR_OTHER          0.0     0.0000        0.0017
# NBR_KEY_CASE       0.0     0.0017        0.0000

# %%
# 2.2 LAG Analysis:
import warnings
# Function to test lag correlation analysis
def test_lag_correlation(target, regressor, max_lag=24):
    correlations = {}
    
    for lag in range(0, max_lag + 1):
        with warnings.catch_warnings():
             warnings.simplefilter("ignore", category=pd.errors.PerformanceWarning)
        df[f'{regressor}_LAG_{lag}'] = df[regressor].shift(lag)
        correlations[lag] = df[[target, f'{regressor}_LAG_{lag}']].corr().iloc[0, 1]
    
    correlation_df = pd.DataFrame(list(correlations.items()), columns=['Lag (Months)', 'Correlation'])
    best_lag = correlation_df.iloc[correlation_df['Correlation'].abs().idxmax()]
    
    print(f"Best Lag for {regressor}: {best_lag['Lag (Months)']} months (Correlation = {best_lag['Correlation']:.2f})")
    
    plt.figure(figsize=(5, 3))
    plt.plot(correlation_df['Lag (Months)'], correlation_df['Correlation'], marker='o', linestyle='dashed', label=regressor)
    plt.axvline(x=12, color='red', linestyle='dotted', label="12-Month Lag")
    plt.axhline(y=0, color='black', linestyle='dashed')
    plt.xlabel("Lag (Months)")
    plt.ylabel("Correlation with TOT_PAID")
    plt.title(f"Correlation of {regressor} at Different Lags with TOT_PAID")
    plt.legend()
    plt.grid(True)
    plt.show()
    
    return best_lag


# Test lag correlation for EST_COST, NBR_KEY_CASE, NBR_OTHER and NBR_CASE
best_est_cost_lag = test_lag_correlation('TOT_PAID', 'EST_COST')
best_key_case_lag = test_lag_correlation('TOT_PAID', 'NBR_KEY_CASE')
best_case_lag = test_lag_correlation('TOT_PAID', 'NBR_CASE')
best_other_case_lag = test_lag_correlation('TOT_PAID', 'NBR_OTHER')

# Run Granger Causality Test for each regressor
print("\nRunning Granger Causality Test (Does EST_COST Granger-cause TOT_PAID?)")
granger_budget = grangercausalitytests(df[['TOT_PAID', 'EST_COST']].dropna(), best_est_cost_lag['Lag (Months)'])

print("\nRunning Granger Causality Test (Does NBR_KEY_CASE Granger-cause TOT_PAID?)")
granger_murder = grangercausalitytests(df[['TOT_PAID', 'NBR_KEY_CASE']].dropna(), best_key_case_lag['Lag (Months)'])

print("\nRunning Granger Causality Test (Does NBR_CASE Granger-cause TOT_PAID?)")
granger_case = grangercausalitytests(df[['TOT_PAID', 'NBR_CASE']].dropna(), best_case_lag['Lag (Months)'])

print("\nRunning Granger Causality Test (Does NBR_OTHER Granger-cause TOT_PAID?)")
granger_case = grangercausalitytests(df[['TOT_PAID', 'NBR_OTHER']].dropna(), best_other_case_lag['Lag (Months)'])

#Output: there is a significant correlation btweent the target value and features at lag 12 which is statistically confirmed by Granger Cause test.
# It means that features are Granger Causing TOT_PAID at lag 12 
# What does it mean? The value of Nbr of Cases and also Est Cost after 12 months (lag 12) shows a siginificant impact (correlation) on Total Expenditure
# Out:
# Best Lag for EST_COST: 12.0 months (Correlation = 0.70)
# Best Lag for NBR_KEY_CASE: 12.0 months (Correlation = 0.34)
# Best Lag for NBR_CASE: 12.0 months (Correlation = 0.53)
# Best Lag for NBR_OTHER: 12.0 months (Correlation = 0.47)
# Running Granger Causality Test (Does EST_COST Granger-cause TOT_PAID?)
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.4384  , p=0.2321  , df_denom=163, df_num=1
# ssr based chi2 test:   chi2=1.4649  , p=0.2262  , df=1
# likelihood ratio test: chi2=1.4584  , p=0.2272  , df=1
# parameter F test:         F=1.4384  , p=0.2321  , df_denom=163, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.3848  , p=0.0954  , df_denom=160, df_num=2
# ssr based chi2 test:   chi2=4.9187  , p=0.0855  , df=2
# likelihood ratio test: chi2=4.8468  , p=0.0886  , df=2
# parameter F test:         F=2.3848  , p=0.0954  , df_denom=160, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.2312  , p=0.3003  , df_denom=157, df_num=3
# ssr based chi2 test:   chi2=3.8583  , p=0.2772  , df=3
# likelihood ratio test: chi2=3.8136  , p=0.2823  , df=3
# parameter F test:         F=1.2312  , p=0.3003  , df_denom=157, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0065  , p=0.4060  , df_denom=154, df_num=4
# ssr based chi2 test:   chi2=4.2611  , p=0.3718  , df=4
# likelihood ratio test: chi2=4.2063  , p=0.3788  , df=4
# parameter F test:         F=1.0065  , p=0.4060  , df_denom=154, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.8130  , p=0.5421  , df_denom=151, df_num=5
# ssr based chi2 test:   chi2=4.3613  , p=0.4987  , df=5
# likelihood ratio test: chi2=4.3036  , p=0.5066  , df=5
# parameter F test:         F=0.8130  , p=0.5421  , df_denom=151, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8560  , p=0.5289  , df_denom=148, df_num=6
# ssr based chi2 test:   chi2=5.5872  , p=0.4710  , df=6
# likelihood ratio test: chi2=5.4925  , p=0.4824  , df=6
# parameter F test:         F=0.8560  , p=0.5289  , df_denom=148, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.8011  , p=0.5876  , df_denom=145, df_num=7
# ssr based chi2 test:   chi2=6.1881  , p=0.5180  , df=7
# likelihood ratio test: chi2=6.0715  , p=0.5314  , df=7
# parameter F test:         F=0.8011  , p=0.5876  , df_denom=145, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.7121  , p=0.6805  , df_denom=142, df_num=8
# ssr based chi2 test:   chi2=6.3788  , p=0.6049  , df=8
# likelihood ratio test: chi2=6.2542  , p=0.6188  , df=8
# parameter F test:         F=0.7121  , p=0.6805  , df_denom=142, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.4971  , p=0.1546  , df_denom=139, df_num=9
# ssr based chi2 test:   chi2=15.3160 , p=0.0826  , df=9
# likelihood ratio test: chi2=14.6184 , p=0.1020  , df=9
# parameter F test:         F=1.4971  , p=0.1546  , df_denom=139, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3636  , p=0.2037  , df_denom=136, df_num=10
# ssr based chi2 test:   chi2=15.7411 , p=0.1073  , df=10
# likelihood ratio test: chi2=15.0010 , p=0.1320  , df=10
# parameter F test:         F=1.3636  , p=0.2037  , df_denom=136, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.3161  , p=0.2221  , df_denom=133, df_num=11
# ssr based chi2 test:   chi2=16.9811 , p=0.1084  , df=11
# likelihood ratio test: chi2=16.1189 , p=0.1368  , df=11
# parameter F test:         F=1.3161  , p=0.2221  , df_denom=133, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=18.5691 , p=0.0000  , df_denom=130, df_num=12
# ssr based chi2 test:   chi2=265.6810, p=0.0000  , df=12
# likelihood ratio test: chi2=154.7597, p=0.0000  , df=12
# parameter F test:         F=18.5691 , p=0.0000  , df_denom=130, df_num=12
#
# Running Granger Causality Test (Does NBR_KEY_CASE Granger-cause TOT_PAID?)
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=8.0907  , p=0.0050  , df_denom=163, df_num=1
# ssr based chi2 test:   chi2=8.2396  , p=0.0041  , df=1
# likelihood ratio test: chi2=8.0416  , p=0.0046  , df=1
# parameter F test:         F=8.0907  , p=0.0050  , df_denom=163, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.2063  , p=0.0166  , df_denom=160, df_num=2
# ssr based chi2 test:   chi2=8.6756  , p=0.0131  , df=2
# likelihood ratio test: chi2=8.4552  , p=0.0146  , df=2
# parameter F test:         F=4.2063  , p=0.0166  , df_denom=160, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.4847  , p=0.0628  , df_denom=157, df_num=3
# ssr based chi2 test:   chi2=7.7863  , p=0.0506  , df=3
# likelihood ratio test: chi2=7.6071  , p=0.0549  , df=3
# parameter F test:         F=2.4847  , p=0.0628  , df_denom=157, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.9460  , p=0.1056  , df_denom=154, df_num=4
# ssr based chi2 test:   chi2=8.2389  , p=0.0832  , df=4
# likelihood ratio test: chi2=8.0375  , p=0.0902  , df=4
# parameter F test:         F=1.9460  , p=0.1056  , df_denom=154, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.5630  , p=0.1739  , df_denom=151, df_num=5
# ssr based chi2 test:   chi2=8.3845  , p=0.1363  , df=5
# likelihood ratio test: chi2=8.1747  , p=0.1469  , df=5
# parameter F test:         F=1.5630  , p=0.1739  , df_denom=151, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.8566  , p=0.0920  , df_denom=148, df_num=6
# ssr based chi2 test:   chi2=12.1181 , p=0.0594  , df=6
# likelihood ratio test: chi2=11.6837 , p=0.0694  , df=6
# parameter F test:         F=1.8566  , p=0.0920  , df_denom=148, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.7351  , p=0.1052  , df_denom=145, df_num=7
# ssr based chi2 test:   chi2=13.4019 , p=0.0629  , df=7
# likelihood ratio test: chi2=12.8701 , p=0.0753  , df=7
# parameter F test:         F=1.7351  , p=0.1052  , df_denom=145, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.3371  , p=0.2299  , df_denom=142, df_num=8
# ssr based chi2 test:   chi2=11.9778 , p=0.1522  , df=8
# likelihood ratio test: chi2=11.5481 , p=0.1725  , df=8
# parameter F test:         F=1.3371  , p=0.2299  , df_denom=142, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.2213  , p=0.2867  , df_denom=139, df_num=9
# ssr based chi2 test:   chi2=12.4942 , p=0.1869  , df=9
# likelihood ratio test: chi2=12.0248 , p=0.2119  , df=9
# parameter F test:         F=1.2213  , p=0.2867  , df_denom=139, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.0344  , p=0.4181  , df_denom=136, df_num=10
# ssr based chi2 test:   chi2=11.9413 , p=0.2890  , df=10
# likelihood ratio test: chi2=11.5090 , p=0.3193  , df=10
# parameter F test:         F=1.0344  , p=0.4181  , df_denom=136, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.4729  , p=0.1488  , df_denom=133, df_num=11
# ssr based chi2 test:   chi2=19.0037 , p=0.0610  , df=11
# likelihood ratio test: chi2=17.9324 , p=0.0832  , df=11
# parameter F test:         F=1.4729  , p=0.1488  , df_denom=133, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=2.6411  , p=0.0034  , df_denom=130, df_num=12
# ssr based chi2 test:   chi2=37.7881 , p=0.0002  , df=12
# likelihood ratio test: chi2=33.8158 , p=0.0007  , df=12
# parameter F test:         F=2.6411  , p=0.0034  , df_denom=130, df_num=12
#
# Running Granger Causality Test (Does NBR_CASE Granger-cause TOT_PAID?)
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=8.5049  , p=0.0040  , df_denom=163, df_num=1
# ssr based chi2 test:   chi2=8.6615  , p=0.0033  , df=1
# likelihood ratio test: chi2=8.4431  , p=0.0037  , df=1
# parameter F test:         F=8.5049  , p=0.0040  , df_denom=163, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.2781  , p=0.0402  , df_denom=160, df_num=2
# ssr based chi2 test:   chi2=6.7611  , p=0.0340  , df=2
# likelihood ratio test: chi2=6.6262  , p=0.0364  , df=2
# parameter F test:         F=3.2781  , p=0.0402  , df_denom=160, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.2207  , p=0.0879  , df_denom=157, df_num=3
# ssr based chi2 test:   chi2=6.9592  , p=0.0732  , df=3
# likelihood ratio test: chi2=6.8156  , p=0.0780  , df=3
# parameter F test:         F=2.2207  , p=0.0879  , df_denom=157, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.6294  , p=0.1696  , df_denom=154, df_num=4
# ssr based chi2 test:   chi2=6.8985  , p=0.1414  , df=4
# likelihood ratio test: chi2=6.7565  , p=0.1493  , df=4
# parameter F test:         F=1.6294  , p=0.1696  , df_denom=154, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2565  , p=0.2858  , df_denom=151, df_num=5
# ssr based chi2 test:   chi2=6.7401  , p=0.2407  , df=5
# likelihood ratio test: chi2=6.6036  , p=0.2518  , df=5
# parameter F test:         F=1.2565  , p=0.2858  , df_denom=151, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0222  , p=0.4131  , df_denom=148, df_num=6
# ssr based chi2 test:   chi2=6.6722  , p=0.3522  , df=6
# likelihood ratio test: chi2=6.5377  , p=0.3657  , df=6
# parameter F test:         F=1.0222  , p=0.4131  , df_denom=148, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.9341  , p=0.4822  , df_denom=145, df_num=7
# ssr based chi2 test:   chi2=7.2153  , p=0.4068  , df=7
# likelihood ratio test: chi2=7.0573  , p=0.4229  , df=7
# parameter F test:         F=0.9341  , p=0.4822  , df_denom=145, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2441  , p=0.2778  , df_denom=142, df_num=8
# ssr based chi2 test:   chi2=11.1448 , p=0.1936  , df=8
# likelihood ratio test: chi2=10.7715 , p=0.2150  , df=8
# parameter F test:         F=1.2441  , p=0.2778  , df_denom=142, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.6263  , p=0.1133  , df_denom=139, df_num=9
# ssr based chi2 test:   chi2=16.6370 , p=0.0547  , df=9
# likelihood ratio test: chi2=15.8181 , p=0.0708  , df=9
# parameter F test:         F=1.6263  , p=0.1133  , df_denom=139, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.1802  , p=0.3094  , df_denom=136, df_num=10
# ssr based chi2 test:   chi2=13.6247 , p=0.1908  , df=10
# likelihood ratio test: chi2=13.0656 , p=0.2200  , df=10
# parameter F test:         F=1.1802  , p=0.3094  , df_denom=136, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=2.5595  , p=0.0057  , df_denom=133, df_num=11
# ssr based chi2 test:   chi2=33.0234 , p=0.0005  , df=11
# likelihood ratio test: chi2=29.9543 , p=0.0016  , df=11
# parameter F test:         F=2.5595  , p=0.0057  , df_denom=133, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=6.5497  , p=0.0000  , df_denom=130, df_num=12
# ssr based chi2 test:   chi2=93.7113 , p=0.0000  , df=12
# likelihood ratio test: chi2=73.2945 , p=0.0000  , df=12
# parameter F test:         F=6.5497  , p=0.0000  , df_denom=130, df_num=12
#
# Running Granger Causality Test (Does NBR_OTHER Granger-cause TOT_PAID?)
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.3886  , p=0.0377  , df_denom=163, df_num=1
# ssr based chi2 test:   chi2=4.4693  , p=0.0345  , df=1
# likelihood ratio test: chi2=4.4102  , p=0.0357  , df=1
# parameter F test:         F=4.3886  , p=0.0377  , df_denom=163, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.9937  , p=0.1396  , df_denom=160, df_num=2
# ssr based chi2 test:   chi2=4.1120  , p=0.1280  , df=2
# likelihood ratio test: chi2=4.0615  , p=0.1312  , df=2
# parameter F test:         F=1.9937  , p=0.1396  , df_denom=160, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.7050  , p=0.1682  , df_denom=157, df_num=3
# ssr based chi2 test:   chi2=5.3429  , p=0.1483  , df=3
# likelihood ratio test: chi2=5.2577  , p=0.1539  , df=3
# parameter F test:         F=1.7050  , p=0.1682  , df_denom=157, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.3276  , p=0.2621  , df_denom=154, df_num=4
# ssr based chi2 test:   chi2=5.6209  , p=0.2293  , df=4
# likelihood ratio test: chi2=5.5262  , p=0.2374  , df=4
# parameter F test:         F=1.3276  , p=0.2621  , df_denom=154, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2260  , p=0.2996  , df_denom=151, df_num=5
# ssr based chi2 test:   chi2=6.5767  , p=0.2541  , df=5
# likelihood ratio test: chi2=6.4467  , p=0.2651  , df=5
# parameter F test:         F=1.2260  , p=0.2996  , df_denom=151, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7889  , p=0.5799  , df_denom=148, df_num=6
# ssr based chi2 test:   chi2=5.1493  , p=0.5248  , df=6
# likelihood ratio test: chi2=5.0686  , p=0.5350  , df=6
# parameter F test:         F=0.7889  , p=0.5799  , df_denom=148, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.7112  , p=0.6626  , df_denom=145, df_num=7
# ssr based chi2 test:   chi2=5.4931  , p=0.6000  , df=7
# likelihood ratio test: chi2=5.4009  , p=0.6112  , df=7
# parameter F test:         F=0.7112  , p=0.6626  , df_denom=145, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2584  , p=0.2700  , df_denom=142, df_num=8
# ssr based chi2 test:   chi2=11.2721 , p=0.1868  , df=8
# likelihood ratio test: chi2=10.8905 , p=0.2080  , df=8
# parameter F test:         F=1.2584  , p=0.2700  , df_denom=142, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.8228  , p=0.0692  , df_denom=139, df_num=9
# ssr based chi2 test:   chi2=18.6472 , p=0.0284  , df=9
# likelihood ratio test: chi2=17.6264 , p=0.0398  , df=9
# parameter F test:         F=1.8228  , p=0.0692  , df_denom=139, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3518  , p=0.2094  , df_denom=136, df_num=10
# ssr based chi2 test:   chi2=15.6057 , p=0.1115  , df=10
# likelihood ratio test: chi2=14.8780 , p=0.1366  , df=10
# parameter F test:         F=1.3518  , p=0.2094  , df_denom=136, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=2.0742  , p=0.0263  , df_denom=133, df_num=11
# ssr based chi2 test:   chi2=26.7621 , p=0.0050  , df=11
# likelihood ratio test: chi2=24.6993 , p=0.0101  , df=11
# parameter F test:         F=2.0742  , p=0.0263  , df_denom=133, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=4.2300  , p=0.0000  , df_denom=130, df_num=12
# ssr based chi2 test:   chi2=60.5211 , p=0.0000  , df=12
# likelihood ratio test: chi2=51.0932 , p=0.0000  , df=12
# parameter F test:         F=4.2300  , p=0.0000  , df_denom=130, df_num=12

# %%
#2.3 PCA analysis

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


# Standardize the features
features = ['EST_COST', 'NBR_CASE', 'NBR_OTHER', 'NBR_KEY_CASE']
X = df[features]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply PCA
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# Explained variance ratio
explained_var = pca.explained_variance_ratio_
print("\n Explained Variance Ratio per Principal Component:")
for i, var in enumerate(explained_var):
    print(f"PC{i+1}: {var:.4f}")

# Plot cumulative variance
plt.figure(figsize=(5, 3))
plt.plot(range(1, len(explained_var)+1), explained_var.cumsum(), marker='o')
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("PCA - Explained Variance")
plt.grid(True)
plt.tight_layout()
plt.show()

# Feature importance per component (absolute values of loadings)
loadings = pd.DataFrame(
    abs(pca.components_.T),
    columns=[f'PC{i+1}' for i in range(len(features))],
    index=features
)

# Optional: Average importance across all components
loadings['Average Importance'] = loadings.mean(axis=1)
loadings_sorted = loadings.sort_values(by='Average Importance', ascending=False)

print("\n Feature Importance Based on PCA Loadings:")
print(loadings_sorted[['Average Importance']])

# Optional: Heatmap of PCA loadings
plt.figure(figsize=(5, 3))
sns.heatmap(loadings.drop(columns='Average Importance'), annot=True, cmap='viridis')
plt.title("PCA Loadings Heatmap")
plt.tight_layout()
plt.show()

#output: the most important feature factor in this analysis is: NBR_OTHER and the 2nd (if applicable)would be EST_COST.
# because of the math equation between NBR_CASE, NBR_KEY_OTHER and NBR_OTHER

#Conclustion: at the end of step 2 we can conclude that: Target value is 'TOT_PAID', Features at lag 12: 'NBR_OTHER' and 'EST_COST' 
# Therefore, we can start the Model Fitting at the next step
# Out:
#  Explained Variance Ratio per Principal Component:
# PC1: 0.6934
# PC2: 0.1955
# PC3: 0.1111
# PC4: 0.0000
#  Feature Importance Based on PCA Loadings:
#               Average Importance
# NBR_OTHER               0.489133
# NBR_CASE                0.430779
# NBR_KEY_CASE            0.427243
# EST_COST                0.352642

# %% [markdown]
# Step 3: Model Fitting and measuring model's accuracy by RMSE, MAE, MAPE
#
# Testing various time series methods and measuring the effect of seasonality and regressors in the model. Selecting the best method with the most useful regressors based on their accuracy measured by RMSE, MAE and MAPE.

# %%
#3.1 Model Search

from prophet.plot import plot_components_plotly

df = data[['ACC_MONTH', 'TOT_PAID', 'EST_COST', 'NBR_CASE', 'NBR_KEY_CASE','NBR_OTHER']].dropna()

df['ds'] = pd.to_datetime(df['ACC_MONTH'])
df['y'] = df['TOT_PAID']
df = df.sort_values('ds').reset_index(drop=True)


# Step 1: Create 12-month lagged features for selected regressors
lag = 12
regressors = ['EST_COST', 'NBR_OTHER']  # Reduced to just these two #, 'NBR_CASE', 'NBR_KEY_CASE'

for reg in regressors:
    df[f'{reg}_lag{lag}'] = df[reg].shift(lag)

# Drop NA caused by lag
df_model = df.dropna().copy().reset_index(drop=True)

# Step 2: PCA on lagged features
lagged_features = [f'{reg}_lag{lag}' for reg in regressors]
X = df_model[lagged_features]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)
df_model['PC1'] = X_pca[:, 0]
df_model['PC2'] = X_pca[:, 1]
#df_model['PC3'] = X_pca[:, 2]
#df_model['PC4'] = X_pca[:, 3]

# Step 3: Prepare Prophet data
df_model['ds'] = df_model['ds']
df_model['y'] = df_model['y']

# Step 4: Split into train/test (last 18 months for evaluation)
train = df_model[:-18]
test = df_model[-18:]

# Step 5: Fit Prophet model with PC1 & PC2
model = Prophet(yearly_seasonality=True,changepoint_prior_scale=0.1)


model.add_regressor('PC1')
model.add_regressor('PC2')
#model.add_regressor('PC3')
#model.add_regressor('PC4')
model.fit(train[['ds', 'y', 'PC1', 'PC2']])#,'PC3','PC4']]) 

# Step 6: Evaluate using historical test set
forecast_test = model.predict(test[['ds', 'PC1', 'PC2']])#,'PC3','PC4']]) #
rmse = np.sqrt(mean_squared_error(test['y'], forecast_test['yhat']))
mae = mean_absolute_error(test['y'], forecast_test['yhat'])

actual = test['y'].values
predicted = forecast_test['yhat'].values
nonzero_mask = actual != 0
actual_nonzero = actual[nonzero_mask]
predicted_nonzero = predicted[nonzero_mask]
mape = np.mean(np.abs((actual_nonzero - predicted_nonzero) / actual_nonzero)) * 100 if len(actual_nonzero) > 0 else np.nan

print("\n Historical Forecast Accuracy (last 18 months):")
print(f"RMSE: {rmse:,.2f}")
print(f"MAE: {mae:,.2f}")
print(f"MAPE: {mape:.2f}%")

# Use this if you want an interactive Plotly version:
plot_components_plotly(model, forecast_test)
# Static matplotlib version
fig = model.plot_components(forecast_test)

#output: the model's accuracy is in a very good level so we have good confindece about its performance for future data
# Prophet plot component also shows that the model has a steady increasing trend, complex seasonality effect and decent influence of regressors (PC1 & PC2)
# Out:
# 12:41:59 - cmdstanpy - INFO - Chain [1] start processing
# 12:42:00 - cmdstanpy - INFO - Chain [1] done processing
#  Historical Forecast Accuracy (last 18 months):
# RMSE: 199,860.27
# MAE: 168,042.88
# MAPE: 6.28%

# %% [markdown]
# Step 4: Forecasting 18 months to the future
#
# Forecasting regressors for 18 months future to be used for forecasting 18 months future total expenditures

# %%
# --- STEP 4: Forecast Future TOT_PAID using Forecasted Regressors ---


future_regressors = {}
forecast_horizon = 6 

for reg in regressors:
    df_reg = df_model[['ds', reg]].rename(columns={reg: 'y'})
    reg_model = Prophet(yearly_seasonality=True,changepoint_prior_scale=0.1)
    reg_model.fit(df_reg)
    
    future_dates = reg_model.make_future_dataframe(periods=forecast_horizon + lag, freq='MS')
    reg_forecast = reg_model.predict(future_dates)
    
    future_regressors[reg] = reg_forecast[['ds', 'yhat']].rename(columns={'yhat': f'{reg}_forecast'})

# Step B: Combine regressor forecasts
future_df = future_regressors[regressors[0]].copy()
for reg in regressors[1:]:
    future_df = future_df.merge(future_regressors[reg], on='ds')

# Step C: Apply lag 12 to forecasted features
for reg in regressors:
    future_df[f'{reg}_lag12'] = future_df[f'{reg}_forecast'].shift(12)

# Drop rows with NA from lagging
future_df = future_df.dropna().reset_index(drop=True)

# Step D: PCA on lagged forecasted features
future_X = future_df[[f'{reg}_lag12' for reg in regressors]]
future_X_scaled = scaler.transform(future_X)
future_X_pca = pca.transform(future_X_scaled)
future_df['PC1'] = future_X_pca[:, 0]
future_df['PC2'] = future_X_pca[:, 1]

# Step E: Forecast should start right after last actual data
last_actual_date = df_model['ds'].max()
future_input = future_df[future_df['ds'] > last_actual_date][['ds', 'PC1', 'PC2']].head(18)

# Step F: Forecast TOT_PAID for next 18 months
future_forecast = model.predict(future_input)

# --- Print Forecasted TOT_PAID for Next 18 Months ---
print("\n Forecasted TOT_PAID (Next 18 Months):")
forecast_columns = ['ds', 'yhat', 'yhat_lower', 'yhat_upper']
print(future_forecast[forecast_columns].to_string(index=False))

#output: we have 18 month of future forecast for total expenditures which gives the chance to forecast one full year (next year from the middle of current year)
# Out:
# 12:57:09 - cmdstanpy - INFO - Chain [1] start processing
# 12:57:09 - cmdstanpy - INFO - Chain [1] done processing
# 12:57:10 - cmdstanpy - INFO - Chain [1] start processing
# 12:57:10 - cmdstanpy - INFO - Chain [1] done processing
#  Forecasted TOT_PAID (Next 18 Months):
#         ds         yhat   yhat_lower   yhat_upper
# 2025-03-01 3.067176e+06 2.798048e+06 3.326943e+06
# 2025-04-01 2.616903e+06 2.359724e+06 2.875667e+06
# 2025-05-01 3.258239e+06 3.000243e+06 3.517179e+06
# 2025-06-01 2.693802e+06 2.432782e+06 2.970424e+06
# 2025-07-01 2.383051e+06 2.128064e+06 2.659642e+06
# 2025-08-01 2.673726e+06 2.399736e+06 2.912135e+06
# 2025-09-01 2.553611e+06 2.270736e+06 2.809477e+06
# 2025-10-01 2.590206e+06 2.332406e+06 2.871506e+06
# 2025-11-01 3.060604e+06 2.775929e+06 3.320690e+06
# 2025-12-01 2.529827e+06 2.267551e+06 2.812105e+06
# 2026-01-01 2.516646e+06 2.249019e+06 2.777638e+06
# 2026-02-01 2.807208e+06 2.566677e+06 3.073158e+06
# 2026-03-01 2.789440e+06 2.526949e+06 3.049048e+06
# 2026-04-01 2.494904e+06 2.246822e+06 2.767546e+06
# 2026-05-01 3.628721e+06 3.359093e+06 3.910214e+06
# 2026-06-01 2.469715e+06 2.205932e+06 2.722994e+06
# 2026-07-01 2.672089e+06 2.413761e+06 2.914858e+06
# 2026-08-01 2.753693e+06 2.495472e+06 3.007989e+06

# %% [markdown]
# Step 5: Analysing the outupt - Plotting the trends and forecasts

# %%
# --- Final Plot: Actuals + Model Prediction (Train + Test) + Forecast ---
# --- Predictions on train set for plotting ---
forecast_train = model.predict(train[['ds', 'PC1', 'PC2']])
forecast_all = pd.concat([forecast_train[['ds', 'yhat']], forecast_test[['ds', 'yhat']]], ignore_index=True)
forecast_all = forecast_all.sort_values('ds').reset_index(drop=True)


plt.figure(figsize=(10, 4))

plt.plot(df_model['ds'], df_model['y'], label='Actual TOT_PAID', color='black')
plt.plot(forecast_all['ds'], forecast_all['yhat'], label='Model Prediction (Train + Test)', color='green', linestyle='--')
plt.plot(future_forecast['ds'], future_forecast['yhat'], label='Forecast (Next 18 Months)', color='blue', linestyle='--')

plt.fill_between(future_forecast['ds'],
                 future_forecast['yhat_lower'],
                 future_forecast['yhat_upper'],
                 color='blue', alpha=0.2, label='Forecast Confidence Interval')

plt.axvline(x=test['ds'].min(), color='red', linestyle='dashed', label='Test Period Start')
plt.axvline(x=future_forecast['ds'].min(), color='purple', linestyle='dashed', label='Future Forecast Start')

plt.title("Total Expenditure - Actuals, Model Predictions (Train+Test), and 18-Month Forecast")
plt.xlabel("Date")
plt.ylabel("TOT_PAID")
plt.legend(loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()


# --- Plot Each Regressor: Actual + In-sample Fit + 6-Month Forecast ---
print("\n Plotting Actual + Forecasts for Each Regressor (Only Necessary 6-Month Forecast)...")

for reg in regressors:
    df_reg = df_model[['ds', reg]].rename(columns={reg: 'y'})
    reg_model = Prophet(yearly_seasonality=True,)
    reg_model.fit(df_reg)
    
    # Only forecast 6 + lag months (e.g., 18 months if lag=12)
    future_dates = reg_model.make_future_dataframe(periods=lag + 6, freq='MS')
    forecast = reg_model.predict(future_dates)
    
    plt.figure(figsize=(9, 3))
    plt.plot(df_reg['ds'], df_reg['y'], color='black', label='Actual')
    
    fitted = forecast[forecast['ds'].isin(df_reg['ds'])]
    plt.plot(fitted['ds'], fitted['yhat'], color='green', linestyle='--', label='In-sample Prediction')
    
    forecast_future = forecast[forecast['ds'] > df_reg['ds'].max()]
    plt.plot(forecast_future['ds'], forecast_future['yhat'], color='blue', linestyle='--', label='Forecast (Only Needed 6 Months)')
    
    plt.fill_between(forecast_future['ds'], 
                     forecast_future['yhat_lower'], 
                     forecast_future['yhat_upper'], 
                     color='blue', alpha=0.2, label='Confidence Interval')
    
    plt.axvline(x=df_reg['ds'].max(), color='red', linestyle='dashed', label='Forecast Start')
    plt.title(f"{reg} - Actual, Fitted, and 6-Month Forecast for Future TOT_PAID")
    plt.xlabel("Date")
    plt.ylabel(reg)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# 12:57:17 - cmdstanpy - INFO - Chain [1] start processing
# 12:57:17 - cmdstanpy - INFO - Chain [1] done processing
#  Plotting Actual + Forecasts for Each Regressor (Only Necessary 6-Month Forecast)...
# 12:57:18 - cmdstanpy - INFO - Chain [1] start processing
# 12:57:18 - cmdstanpy - INFO - Chain [1] done processing
